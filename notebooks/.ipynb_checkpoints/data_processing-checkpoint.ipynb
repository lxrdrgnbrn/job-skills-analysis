# %%
import pandas as pd
import spacy
import time
import gc
import psutil
import ast

from spacy.matcher import PhraseMatcher
from skillNer.general_params import SKILL_DB
from skillNer.skill_extractor_class import SkillExtractor

# %%
RAW_DATA_PATH = '../data/raw/'
PR_DATA_PATH = '../data/processed/'
data_raw = 'requirements_data_raw.csv'
cleaned_data_raw = 'requirements_data_raw_cleaned.csv'

# %%
data = pd.read_csv(f'{RAW_DATA_PATH}{data_raw}')

data['requirements'] = data['requirements'].replace(r'^\s*$', pd.NA, regex=True)
data = data.dropna(subset=['requirements'])

data.to_csv(f'{RAW_DATA_PATH}{cleaned_data_raw}', index=False)

# %%
nlp = spacy.load("en_core_web_lg")
skill_extractor = SkillExtractor(nlp, SKILL_DB, PhraseMatcher)
nlp_used = skill_extractor.nlp 
print(nlp_used.pipe_names)
print("Vectors:", nlp_used.vocab.vectors_length)
# Out:
# loading full_matcher ...
# loading abv_matcher ...
# loading full_uni_matcher ...
# loading low_form_matcher ...
# loading token_matcher ...
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']
# Vectors: 300

# %%
def extract_hard_skills(text):
    time.sleep(0.2)
    print(f"Memory usage: {psutil.virtual_memory().percent}%")
    print(f"Processing text: {text[:100]}..." if len(text) > 100 else f"Processing text: {text}")
    
    if not isinstance(text, str) or text.strip() == '':
        print("  → Empty or invalid text, returning []")
        return []
    
    try:
        annotations = skill_extractor.annotate(text)
        print(f"  → Found annotations: keys={list(annotations.keys())}, results keys={list(annotations['results'].keys())}")

        ngram_scored = annotations['results']['ngram_scored']
        print(f"  → ngram_scored count: {len(ngram_scored)}")

        skills = [item['doc_node_value'] for item in ngram_scored]
        print(f"  → Extracted skills: {skills}")

        return skills

    except KeyError as e:
        print(f"KeyError: missing key {e}")
        return []
    except Exception as e:
        print(f"Unexpected error: {type(e).__name__}: {e}")
        return []

batch_size = 5
results = []
cleaned_data = pd.read_csv(f'{RAW_DATA_PATH}{cleaned_data_raw}')

for i in range(0, len(cleaned_data), batch_size):
    print(f"Processing batch {i}–{i+batch_size}...")
    
    batch = cleaned_data.iloc[i:i+batch_size].copy()
    batch['requirements'] = batch['requirements'].apply(extract_hard_skills)
    
    results.append(batch)
    
    time.sleep(1)
    gc.collect()   

final_data = pd.concat(results, ignore_index=True)
final_data.to_csv(f'{RAW_DATA_PATH}requirements_data_processed.csv', index=False)
print('Done!')
# Out:
# Processing batch 0–5...
# Memory usage: 32.8%
# Processing text: Data Science
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 0
#   → Extracted skills: []
# Memory usage: 32.8%
# Processing text: Data Science
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 0
#   → Extracted skills: []
# Memory usage: 32.9%
# Processing text: Python, RAG, LLM, Deep Learning
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 1
#   → Extracted skills: ['python']
# Memory usage: 32.9%
# Processing text: Python, Clickhouse, Hadoop, PostgreSQL, хорошее знание математической статистики и методик статистич...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 9
#   → Extracted skills: ['python', 'postgresql', 'python', 'numpy', 'pandas', 'scipy', 'matplotlib', 'pyspark', 'sql']
# Memory usage: 32.9%
# Processing text: Python, SQL, NoSQL, Big Data, Data Engineer, Математический анализ, Математическая статистика, Алгор...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 4
#   → Extracted skills: ['python', 'sql', 'nosql', 'data engineer']
# Processing batch 5–10...
# Memory usage: 33.0%
# Processing text: ETL, Cognos BI, MS SQL, Power BI
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 1
#   → Extracted skills: ['sql']
# Memory usage: 33.0%
# Processing text: SQL, A/B тесты, Python
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 3
#   → Extracted skills: ['sql', 'b', 'python']
# Memory usage: 33.0%
# Processing text: Системный анализ, аналитик данных, Teradata, SQL
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 0
#   → Extracted skills: []
# Memory usage: 33.0%
# Processing text: SQL, Python, Power BI, Опыт работы аналитиком данных от 2 лет, желательно в банке, МФО или финтехе. ...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 11
#   → Extracted skills: ['sql', 'python', 'sql', 'greenplum', 'postgresql', 'python', 'pandas', 'matplotlib', 'seaborn', 'analytics', 'underwriting']
# Memory usage: 32.9%
# Processing text: Анализ бизнес показателей, Power BI, Бизнес-анализ, Анализ данных, MS Power BI, Аналитика, Автоматиз...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 3
#   → Extracted skills: ['vertica', 'tableau tableau', 'qlikview']
# Processing batch 10–15...
# Memory usage: 32.9%
# Processing text: Законченное высшее образование, физико-математическое или техническое; Глубокое понимание и практиче...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 1
#   → Extracted skills: ['python']
# Memory usage: 33.0%
# Processing text: Законченное высшее образование, физико-математическое или техническое; Глубокое понимание и практиче...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 1
#   → Extracted skills: ['python']
# Memory usage: 33.0%
# Processing text: Законченное высшее образование, физико-математическое или техническое; Глубокое понимание и практиче...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 1
#   → Extracted skills: ['python']
# Memory usage: 33.0%
# Processing text: Законченное высшее образование, физико-математическое или техническое; Глубокое понимание и практиче...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 1
#   → Extracted skills: ['python']
# Memory usage: 32.9%
# Processing text: Законченное высшее образование, физико-математическое или техническое; Глубокое понимание и практиче...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 1
#   → Extracted skills: ['python']
# Processing batch 15–20...
# Memory usage: 33.0%
# Processing text: Информационная безопасность
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 0
#   → Extracted skills: []
# Memory usage: 33.0%
# Processing text: SQL, Tableau
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 2
#   → Extracted skills: ['sql', 'tableau']
# Memory usage: 32.8%
# Processing text: SQL, MS Visio, Постановка задач разработчикам, BPMN, Моделирование бизнес процессов, ARIS, Разработк...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 1
#   → Extracted skills: ['sql']
# Memory usage: 32.9%
# Processing text: Python, pandas, Numpy, R, Scikit-learn, Matplotlib, SciPy, Keras, PyTorch, TensorFlow
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 9
#   → Extracted skills: ['python', 'pandas', 'numpy', 'r', 'matplotlib', 'scipy', 'keras', 'pytorch', 'tensorflow']
# Memory usage: 32.9%
# Processing text: MS Excel, 1С, Анализ данных, Работа с большим объемом информации, Аналитическое мышление, Сбор и ана...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 0
#   → Extracted skills: []
# Processing batch 20–25...
# Memory usage: 32.9%
# Processing text: IT, Разработка поисковых технологий, ML
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 0
#   → Extracted skills: []
# Memory usage: 33.0%
# Processing text: Знание MS Office, Умение работать в условиях многозадачности, Сбор и анализ информации
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 0
#   → Extracted skills: []
# Memory usage: 33.0%
# Processing text: SQL, Анализ данных, Работа с большим объемом информации, Визуализация данных, Работа с базами данных...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 1
#   → Extracted skills: ['sql']
# Memory usage: 32.9%
# Processing text: Бизнес-анализ, SQL, Power BI, Аналитическое мышление, Анализ бизнес-процессов, Системный анализ, MS ...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 2
#   → Extracted skills: ['sql', 'python']
# Memory usage: 32.9%
# Processing text: SQL, Аналитические исследования, MS PowerPoint, Работа с базами данных, Прогнозирование, Аналитика, ...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 1
#   → Extracted skills: ['sql']
# Processing batch 25–30...
# Memory usage: 32.9%
# Processing text: SQL, Работа с базами данных, Python, Git
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 3
#   → Extracted skills: ['sql', 'python', 'git']
# Memory usage: 32.8%
# Processing text: VBA, MS SQL, MS Excel
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 1
#   → Extracted skills: ['sql']
# Memory usage: 32.8%
# Processing text: React, Next, TypeScript, SSR, SSG, APP Routes, Zustand, Redux, Git, SPA, FSD, Zod
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 4
#   → Extracted skills: ['react', 'typescript', 'redux', 'git']
# Memory usage: 32.9%
# Processing text: Python, Hadoop, ML, DL, PySpark, опыт работы в моделировании от 1 - 2-х лет в роли аналитика/DS, пон...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 3
#   → Extracted skills: ['python', 'pyspark', 'python']
# Memory usage: 32.9%
# Processing text: Python, Статистический анализ, Numpy, pandas, Flask, Scikit-learn, SQL, Docker, Git, Фундаментальные...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 13
#   → Extracted skills: ['python', 'numpy', 'pandas', 'flask', 'sql', 'docker', 'git', 'python', 'numpy', 'pandas', 'pandas', 'flask', 'swagger']
# Processing batch 30–35...
# Memory usage: 32.9%
# Processing text: СУБД, Arenadata/Green, Plum/Postgre, SQL, Grafana, NumPy, SciPy
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 4
#   → Extracted skills: ['sql', 'grafana', 'numpy', 'scipy']
# Memory usage: 32.9%
# Processing text: PL/SQL, Системный анализ, PostgreSQL, Greenplum, BI, Python, Анализ данных, DataVault, Hadoop, ORACL...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 3
#   → Extracted skills: ['postgresql', 'greenplum', 'python']
# Memory usage: 32.9%
# Processing text: Python, SQL, pandas, A/B тесты
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 4
#   → Extracted skills: ['python', 'sql', 'pandas', 'b']
# Memory usage: 32.9%
# Processing text: Ответственность, Анализ обратной связи, Разработка технических заданий, Управление требованиями, Раз...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 2
#   → Extracted skills: ['uml', 'business studio']
# Memory usage: 32.9%
# Processing text: MS PowerPoint, SQL, DAX, Power BI, Работа с большим объемом информации
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 1
#   → Extracted skills: ['sql']
# Processing batch 35–40...
# Memory usage: 32.9%
# Processing text: SQL, Python, Big Data, Степень бакалавра/магистра в области компьютерных наук, лингвистики, Сильные ...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 16
#   → Extracted skills: ['sql', 'python', 'sql', 'python', 'pandas', 'nltk', 'spacy', 'r', 'parquet', 'avro', 'json', 'data capture', 'cdc', 'gitlab', 'data vault', 'nosql']
# Memory usage: 32.9%
# Processing text: Статистический анализ, Маркетинговый анализ, Математическая статистика, SQL, Методы машинного обучен...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 6
#   → Extracted skills: ['sql', 'data data', 'data data', 'data analysis', 'r', 'python']
# Memory usage: 32.9%
# Processing text: Python, SQL, Анализ данных, Работа с большим объемом информации, Математическая статистика, Извлечен...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 2
#   → Extracted skills: ['python', 'sql']
# Memory usage: 32.9%
# Processing text: Разработка технических заданий, Постановка задач разработчикам, UML, Моделирование бизнес процессов,...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 1
#   → Extracted skills: ['uml']
# Memory usage: 32.9%
# Processing text: Business Analysis, Data Analysis, Marketing Analytics, Machine Learning, LTV Modeling, Python, SQL, ...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 11
#   → Extracted skills: ['data analysis', 'data analysis', 'analysis marketing', 'machine learning', 'python', 'sql', 'data pipelines', 'forecasting', 'tableau', 'leadership', 'economics']
# Processing batch 40–45...
# Memory usage: 32.9%
# Processing text: SQL, Python, Spark, Hadoop
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 2
#   → Extracted skills: ['sql', 'python']
# Memory usage: 32.9%
# Processing text: Аналитика продаж, SQL, Анализ данных, Интерпретация данных, Бизнес-анализ
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 1
#   → Extracted skills: ['sql']
# Memory usage: 32.9%
# Processing text: SQL, Анализ данных, Tableau, Python, R
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 4
#   → Extracted skills: ['sql', 'tableau', 'python', 'r']
# Memory usage: 32.9%
# Processing text: Отличное знание SQL: написание эффективных запросов, работа с процедурами, функциями, индексами, пар...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 3
#   → Extracted skills: ['sql', 'sql', 'python']
# Memory usage: 32.9%
# Processing text: Аналитическое мышление, A/B тесты, Работа с большим объемом информации, Анализ данных, Clickhouse, P...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 1
#   → Extracted skills: ['b']
# Processing batch 45–50...
# Memory usage: 32.9%
# Processing text: Опыт работы в аналитике от 2-х лет; Обязателен опыт работы с low-code платформами, настройки платфор...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 7
#   → Extracted skills: ['c', 'json', 'uml', 'jira', 'redmine', 'agile', 'scrum']
# Memory usage: 32.9%
# Processing text: SQL, Анализ данных, Power BI, Опыт работы с PowerBI Хорошее знание SQL Уверенный пользователь гугл-т...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 2
#   → Extracted skills: ['sql', 'sql']
# Memory usage: 32.9%
# Processing text: PD, Python, SQL, Git, Математическое моделирование, ИЦБ
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 4
#   → Extracted skills: ['pd', 'python', 'sql', 'git']
# Memory usage: 32.8%
# Processing text: MS Power BI, DataEnginer, дашборд, SQL, Python, Работа с системами аналитики
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 2
#   → Extracted skills: ['sql', 'python']
# Memory usage: 32.9%
# Processing text: MS PowerPoint, Исследовательский анализ данных, Power BI, Подготовка презентаций, Визуализация данны...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 0
#   → Extracted skills: []
# Processing batch 50–55...
# Memory usage: 33.0%
# Processing text: Анализ данных, Аналитическое мышление, Power BI, JavaScript, Python, Power Pivot, Высшее образование...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 5
#   → Extracted skills: ['javascript', 'python', 'python', 'java', 'javascript']
# Memory usage: 32.8%
# Processing text: Опыт работы в роли бизнес-аналитика от 5 лет, описания процессов в BPMN-нотации. Понимание методолог...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 1
#   → Extracted skills: ['scrum']
# Memory usage: 32.8%
# Processing text: SQL, Анализ данных, HTTP, REST API, Аналитическое мышление
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 2
#   → Extracted skills: ['sql', 'rest api']
# Memory usage: 32.9%
# Processing text: MS Excel, Английский язык, Работа с большим объемом информации
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 0
#   → Extracted skills: []
# Memory usage: 32.9%
# Processing text: MS Excel, Извлечение данных, Формирование аналитической отчетности, Предобработка данных, Аналитичес...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 0
#   → Extracted skills: []
# Processing batch 55–60...
# Memory usage: 32.9%
# Processing text: SQL, Python, Data Governance
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 3
#   → Extracted skills: ['sql', 'python', 'data governance']
# Memory usage: 32.9%
# Processing text: Бизнес-анализ, SQL, Power BI, DWH, 1С, Анализ данных, Визуализация данных
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 1
#   → Extracted skills: ['sql']
# Memory usage: 32.9%
# Processing text: Аналитическое мышление, Анализ данных, Бизнес-анализ, Работа с большим объемом информации, MS SQL, P...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 2
#   → Extracted skills: ['sql', 'python']
# Memory usage: 32.9%
# Processing text: MS Excel, Аналитическое мышление, Формирование аналитической отчетности, Предобработка данных, Стрес...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 0
#   → Extracted skills: []
# Memory usage: 33.0%
# Processing text: Анализ данных, Big Data, LightGBM, Регрессионный анализ, Jupyter Notebook, SQL, Power BI, Основы баз...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 8
#   → Extracted skills: ['big data', 'sql', 'python', 'bash', 'pandas', 'numpy', 'matplotlib', 'pyspark']
# Processing batch 60–65...
# Memory usage: 33.0%
# Processing text: Бизнес-анализ, Стратегическое планирование, Оптимизация бизнес-процессов, Описание бизнес-процессов,...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 3
#   → Extracted skills: ['camunda', 'bizagi', 'revit']
# Memory usage: 33.0%
# Processing text: Аналитические исследования, Работа с большим объемом информации, MS Excel, MS SQL, MySQL, Power BI, ...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 5
#   → Extracted skills: ['sql', 'mysql', 'sql', 'mysql', 'python']
# Memory usage: 32.9%
# Processing text: Python, Machine Learning, Анализ данных, Git, NLP
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 2
#   → Extracted skills: ['python', 'git']
# Memory usage: 32.9%
# Processing text: SQL, Бизнес-анализ, ETL, Power BI, MS Excel, CRM
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 1
#   → Extracted skills: ['sql']
# Memory usage: 33.0%
# Processing text: SQL, pandas, Plotly, Jupiter, Jupyter Notebook, Высшее образование; Опыт анализа данных и формирован...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 11
#   → Extracted skills: ['sql', 'pandas', 'plotly', 'sql', 'python', 'pandas', 'plotly', 'python', 'python', 'template', 'python']
# Processing batch 65–70...
# Memory usage: 33.1%
# Processing text: Глубокий опыт в анализе и реорганизации таблиц БД (включая партиционирование), Навыки проектирования...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 3
#   → Extracted skills: ['data vault', 'snowflake', 'sql']
# Memory usage: 33.1%
# Processing text: ООП, SQL, MySQL, PHP, Java, высшее/неполное высшее образование; знание языков/стандартов , SQL; знан...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 8
#   → Extracted skills: ['sql', 'mysql', 'php java', 'sql', 'postgresql', 'firebird', 'interbase', 'mysql']
# Memory usage: 33.1%
# Processing text: Анализ данных, SQL, PostgreSQL, Clickhouse, DataLens, Grafana, Продуктовые метрики, Бизнес метрики, ...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 7
#   → Extracted skills: ['sql', 'postgresql', 'grafana', 'b', 'python', 'pandas', 'ad hoc']
# Memory usage: 33.0%
# Processing text: Анализ данных, SQL, PostgreSQL, Clickhouse, DataLens, Grafana, Продуктовые метрики, Бизнес метрики, ...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 7
#   → Extracted skills: ['sql', 'postgresql', 'grafana', 'b', 'python', 'pandas', 'ad hoc']
# Memory usage: 33.1%
# Processing text: Data Science
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 0
#   → Extracted skills: []
# Processing batch 70–75...
# Memory usage: 33.1%
# Processing text: Data Science
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 0
#   → Extracted skills: []
# Memory usage: 33.1%
# Processing text: Python, RAG, LLM, Deep Learning
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 1
#   → Extracted skills: ['python']
# Memory usage: 33.1%
# Processing text: Python, Clickhouse, Hadoop, PostgreSQL, хорошее знание математической статистики и методик статистич...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 9
#   → Extracted skills: ['python', 'postgresql', 'python', 'numpy', 'pandas', 'scipy', 'matplotlib', 'pyspark', 'sql']
# Memory usage: 33.1%
# Processing text: Python, SQL, NoSQL, Big Data, Data Engineer, Математический анализ, Математическая статистика, Алгор...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 4
#   → Extracted skills: ['python', 'sql', 'nosql', 'data engineer']
# Memory usage: 33.1%
# Processing text: ETL, Cognos BI, MS SQL, Power BI
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 1
#   → Extracted skills: ['sql']
# Processing batch 75–80...
# Memory usage: 33.0%
# Processing text: SQL, A/B тесты, Python
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 3
#   → Extracted skills: ['sql', 'b', 'python']
# Memory usage: 33.0%
# Processing text: Системный анализ, аналитик данных, Teradata, SQL
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 0
#   → Extracted skills: []
# Memory usage: 32.9%
# Processing text: SQL, Python, Power BI, Опыт работы аналитиком данных от 2 лет, желательно в банке, МФО или финтехе. ...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 11
#   → Extracted skills: ['sql', 'python', 'sql', 'greenplum', 'postgresql', 'python', 'pandas', 'matplotlib', 'seaborn', 'analytics', 'underwriting']
# Memory usage: 32.9%
# Processing text: Анализ бизнес показателей, Power BI, Бизнес-анализ, Анализ данных, MS Power BI, Аналитика, Автоматиз...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 3
#   → Extracted skills: ['vertica', 'tableau tableau', 'qlikview']
# Memory usage: 32.9%
# Processing text: Законченное высшее образование, физико-математическое или техническое; Глубокое понимание и практиче...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 1
#   → Extracted skills: ['python']
# Processing batch 80–85...
# Memory usage: 32.9%
# Processing text: Законченное высшее образование, физико-математическое или техническое; Глубокое понимание и практиче...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 1
#   → Extracted skills: ['python']
# Memory usage: 32.9%
# Processing text: Законченное высшее образование, физико-математическое или техническое; Глубокое понимание и практиче...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 1
#   → Extracted skills: ['python']
# Memory usage: 33.0%
# Processing text: Законченное высшее образование, физико-математическое или техническое; Глубокое понимание и практиче...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 1
#   → Extracted skills: ['python']
# Memory usage: 33.0%
# Processing text: Законченное высшее образование, физико-математическое или техническое; Глубокое понимание и практиче...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 1
#   → Extracted skills: ['python']
# Memory usage: 33.0%
# Processing text: Информационная безопасность
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 0
#   → Extracted skills: []
# Processing batch 85–90...
# Memory usage: 32.9%
# Processing text: SQL, Tableau
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 2
#   → Extracted skills: ['sql', 'tableau']
# Memory usage: 33.0%
# Processing text: SQL, MS Visio, Постановка задач разработчикам, BPMN, Моделирование бизнес процессов, ARIS, Разработк...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 1
#   → Extracted skills: ['sql']
# Memory usage: 33.0%
# Processing text: Python, pandas, Numpy, R, Scikit-learn, Matplotlib, SciPy, Keras, PyTorch, TensorFlow
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 9
#   → Extracted skills: ['python', 'pandas', 'numpy', 'r', 'matplotlib', 'scipy', 'keras', 'pytorch', 'tensorflow']
# Memory usage: 33.0%
# Processing text: MS Excel, 1С, Анализ данных, Работа с большим объемом информации, Аналитическое мышление, Сбор и ана...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 0
#   → Extracted skills: []
# Memory usage: 33.0%
# Processing text: IT, Разработка поисковых технологий, ML
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 0
#   → Extracted skills: []
# Processing batch 90–95...
# Memory usage: 32.9%
# Processing text: Знание MS Office, Умение работать в условиях многозадачности, Сбор и анализ информации
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 0
#   → Extracted skills: []
# Memory usage: 33.0%
# Processing text: SQL, Анализ данных, Работа с большим объемом информации, Визуализация данных, Работа с базами данных...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 1
#   → Extracted skills: ['sql']
# Memory usage: 33.0%
# Processing text: Бизнес-анализ, SQL, Power BI, Аналитическое мышление, Анализ бизнес-процессов, Системный анализ, MS ...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 2
#   → Extracted skills: ['sql', 'python']
# Memory usage: 33.0%
# Processing text: SQL, Аналитические исследования, MS PowerPoint, Работа с базами данных, Прогнозирование, Аналитика, ...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 1
#   → Extracted skills: ['sql']
# Memory usage: 33.0%
# Processing text: SQL, Работа с базами данных, Python, Git
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 3
#   → Extracted skills: ['sql', 'python', 'git']
# Processing batch 95–100...
# Memory usage: 32.9%
# Processing text: VBA, MS SQL, MS Excel
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 1
#   → Extracted skills: ['sql']
# Memory usage: 32.9%
# Processing text: React, Next, TypeScript, SSR, SSG, APP Routes, Zustand, Redux, Git, SPA, FSD, Zod
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 4
#   → Extracted skills: ['react', 'typescript', 'redux', 'git']
# Memory usage: 32.9%
# Processing text: Python, Hadoop, ML, DL, PySpark, опыт работы в моделировании от 1 - 2-х лет в роли аналитика/DS, пон...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 3
#   → Extracted skills: ['python', 'pyspark', 'python']
# Memory usage: 33.0%
# Processing text: Python, Статистический анализ, Numpy, pandas, Flask, Scikit-learn, SQL, Docker, Git, Фундаментальные...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 13
#   → Extracted skills: ['python', 'numpy', 'pandas', 'flask', 'sql', 'docker', 'git', 'python', 'numpy', 'pandas', 'pandas', 'flask', 'swagger']
# Memory usage: 33.0%
# Processing text: СУБД, Arenadata/Green, Plum/Postgre, SQL, Grafana, NumPy, SciPy
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 4
#   → Extracted skills: ['sql', 'grafana', 'numpy', 'scipy']
# Processing batch 100–105...
# Memory usage: 33.0%
# Processing text: PL/SQL, Системный анализ, PostgreSQL, Greenplum, BI, Python, Анализ данных, DataVault, Hadoop, ORACL...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 3
#   → Extracted skills: ['postgresql', 'greenplum', 'python']
# Memory usage: 33.0%
# Processing text: Python, SQL, pandas, A/B тесты
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 4
#   → Extracted skills: ['python', 'sql', 'pandas', 'b']
# Memory usage: 33.0%
# Processing text: Ответственность, Анализ обратной связи, Разработка технических заданий, Управление требованиями, Раз...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 2
#   → Extracted skills: ['uml', 'business studio']
# Memory usage: 33.0%
# Processing text: MS PowerPoint, SQL, DAX, Power BI, Работа с большим объемом информации
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 1
#   → Extracted skills: ['sql']
# Memory usage: 33.0%
# Processing text: SQL, Python, Big Data, Степень бакалавра/магистра в области компьютерных наук, лингвистики, Сильные ...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 16
#   → Extracted skills: ['sql', 'python', 'sql', 'python', 'pandas', 'nltk', 'spacy', 'r', 'parquet', 'avro', 'json', 'data capture', 'cdc', 'gitlab', 'data vault', 'nosql']
# Processing batch 105–110...
# Memory usage: 33.0%
# Processing text: Статистический анализ, Маркетинговый анализ, Математическая статистика, SQL, Методы машинного обучен...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 6
#   → Extracted skills: ['sql', 'data data', 'data data', 'data analysis', 'r', 'python']
# Memory usage: 33.0%
# Processing text: Python, SQL, Анализ данных, Работа с большим объемом информации, Математическая статистика, Извлечен...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 2
#   → Extracted skills: ['python', 'sql']
# Memory usage: 32.9%
# Processing text: Разработка технических заданий, Постановка задач разработчикам, UML, Моделирование бизнес процессов,...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 1
#   → Extracted skills: ['uml']
# Memory usage: 32.9%
# Processing text: Business Analysis, Data Analysis, Marketing Analytics, Machine Learning, LTV Modeling, Python, SQL, ...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 11
#   → Extracted skills: ['data analysis', 'data analysis', 'analysis marketing', 'machine learning', 'python', 'sql', 'data pipelines', 'forecasting', 'tableau', 'leadership', 'economics']
# Memory usage: 33.0%
# Processing text: SQL, Python, Spark, Hadoop
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 2
#   → Extracted skills: ['sql', 'python']
# Processing batch 110–115...
# Memory usage: 33.0%
# Processing text: Аналитика продаж, SQL, Анализ данных, Интерпретация данных, Бизнес-анализ
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 1
#   → Extracted skills: ['sql']
# Memory usage: 33.0%
# Processing text: SQL, Анализ данных, Tableau, Python, R
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 4
#   → Extracted skills: ['sql', 'tableau', 'python', 'r']
# Memory usage: 33.0%
# Processing text: Отличное знание SQL: написание эффективных запросов, работа с процедурами, функциями, индексами, пар...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 3
#   → Extracted skills: ['sql', 'sql', 'python']
# Memory usage: 33.0%
# Processing text: Аналитическое мышление, A/B тесты, Работа с большим объемом информации, Анализ данных, Clickhouse, P...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 1
#   → Extracted skills: ['b']
# Memory usage: 33.0%
# Processing text: Опыт работы в аналитике от 2-х лет; Обязателен опыт работы с low-code платформами, настройки платфор...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 7
#   → Extracted skills: ['c', 'json', 'uml', 'jira', 'redmine', 'agile', 'scrum']
# Processing batch 115–120...
# Memory usage: 33.0%
# Processing text: SQL, Анализ данных, Power BI, Опыт работы с PowerBI Хорошее знание SQL Уверенный пользователь гугл-т...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 2
#   → Extracted skills: ['sql', 'sql']
# Memory usage: 33.0%
# Processing text: PD, Python, SQL, Git, Математическое моделирование, ИЦБ
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 4
#   → Extracted skills: ['pd', 'python', 'sql', 'git']
# Memory usage: 33.0%
# Processing text: MS Power BI, DataEnginer, дашборд, SQL, Python, Работа с системами аналитики
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 2
#   → Extracted skills: ['sql', 'python']
# Memory usage: 33.0%
# Processing text: MS PowerPoint, Исследовательский анализ данных, Power BI, Подготовка презентаций, Визуализация данны...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 0
#   → Extracted skills: []
# Memory usage: 33.0%
# Processing text: Анализ данных, Аналитическое мышление, Power BI, JavaScript, Python, Power Pivot, Высшее образование...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 5
#   → Extracted skills: ['javascript', 'python', 'python', 'java', 'javascript']
# Processing batch 120–125...
# Memory usage: 33.0%
# Processing text: Опыт работы в роли бизнес-аналитика от 5 лет, описания процессов в BPMN-нотации. Понимание методолог...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 1
#   → Extracted skills: ['scrum']
# Memory usage: 33.0%
# Processing text: SQL, Анализ данных, HTTP, REST API, Аналитическое мышление
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 2
#   → Extracted skills: ['sql', 'rest api']
# Memory usage: 33.0%
# Processing text: MS Excel, Английский язык, Работа с большим объемом информации
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 0
#   → Extracted skills: []
# Memory usage: 33.0%
# Processing text: MS Excel, Извлечение данных, Формирование аналитической отчетности, Предобработка данных, Аналитичес...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 0
#   → Extracted skills: []
# Memory usage: 33.0%
# Processing text: SQL, Python, Data Governance
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 3
#   → Extracted skills: ['sql', 'python', 'data governance']
# Processing batch 125–130...
# Memory usage: 33.0%
# Processing text: Бизнес-анализ, SQL, Power BI, DWH, 1С, Анализ данных, Визуализация данных
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 1
#   → Extracted skills: ['sql']
# Memory usage: 32.9%
# Processing text: Аналитическое мышление, Анализ данных, Бизнес-анализ, Работа с большим объемом информации, MS SQL, P...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 2
#   → Extracted skills: ['sql', 'python']
# Memory usage: 32.9%
# Processing text: MS Excel, Аналитическое мышление, Формирование аналитической отчетности, Предобработка данных, Стрес...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 0
#   → Extracted skills: []
# Memory usage: 32.9%
# Processing text: Анализ данных, Big Data, LightGBM, Регрессионный анализ, Jupyter Notebook, SQL, Power BI, Основы баз...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 8
#   → Extracted skills: ['big data', 'sql', 'python', 'bash', 'pandas', 'numpy', 'matplotlib', 'pyspark']
# Memory usage: 32.9%
# Processing text: Бизнес-анализ, Стратегическое планирование, Оптимизация бизнес-процессов, Описание бизнес-процессов,...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 3
#   → Extracted skills: ['camunda', 'bizagi', 'revit']
# Processing batch 130–135...
# Memory usage: 32.9%
# Processing text: Аналитические исследования, Работа с большим объемом информации, MS Excel, MS SQL, MySQL, Power BI, ...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 5
#   → Extracted skills: ['sql', 'mysql', 'sql', 'mysql', 'python']
# Memory usage: 33.0%
# Processing text: Python, Machine Learning, Анализ данных, Git, NLP
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 2
#   → Extracted skills: ['python', 'git']
# Memory usage: 33.0%
# Processing text: SQL, Бизнес-анализ, ETL, Power BI, MS Excel, CRM
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 1
#   → Extracted skills: ['sql']
# Memory usage: 33.0%
# Processing text: SQL, pandas, Plotly, Jupiter, Jupyter Notebook, Высшее образование; Опыт анализа данных и формирован...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 11
#   → Extracted skills: ['sql', 'pandas', 'plotly', 'sql', 'python', 'pandas', 'plotly', 'python', 'python', 'template', 'python']
# Memory usage: 32.9%
# Processing text: Глубокий опыт в анализе и реорганизации таблиц БД (включая партиционирование), Навыки проектирования...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 3
#   → Extracted skills: ['data vault', 'snowflake', 'sql']
# Processing batch 135–140...
# Memory usage: 32.9%
# Processing text: ООП, SQL, MySQL, PHP, Java, высшее/неполное высшее образование; знание языков/стандартов , SQL; знан...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 8
#   → Extracted skills: ['sql', 'mysql', 'php java', 'sql', 'postgresql', 'firebird', 'interbase', 'mysql']
# Memory usage: 33.0%
# Processing text: Анализ данных, SQL, PostgreSQL, Clickhouse, DataLens, Grafana, Продуктовые метрики, Бизнес метрики, ...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 7
#   → Extracted skills: ['sql', 'postgresql', 'grafana', 'b', 'python', 'pandas', 'ad hoc']
# Memory usage: 33.0%
# Processing text: Анализ данных, SQL, PostgreSQL, Clickhouse, DataLens, Grafana, Продуктовые метрики, Бизнес метрики, ...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 7
#   → Extracted skills: ['sql', 'postgresql', 'grafana', 'b', 'python', 'pandas', 'ad hoc']
# Memory usage: 33.0%
# Processing text: pandas, Numpy, Matplotlib, Plotly, Tableau, Power BI, Python, PostgreSQL, Clickhouse
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 7
#   → Extracted skills: ['pandas', 'numpy', 'matplotlib', 'plotly', 'tableau', 'python', 'postgresql']
# Memory usage: 33.0%
# Processing text: Python, Big Data, Clickhouse, Time Series Analysis, Golang, SQL, Power BI, blockchain, crypto, Анали...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 3
#   → Extracted skills: ['python', 'sql', 'blockchain']
# Processing batch 140–145...
# Memory usage: 33.0%
# Processing text: Power BI, MS Excel, Анализ данных, Работа с большим объемом информации, Miro, MS Word, MS SQL, Pytho...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 2
#   → Extracted skills: ['sql', 'python']
# Memory usage: 33.0%
# Processing text: Python, PySpark, Hadoop, Математическая статистика, SQL, pandas, Уверенный Python, продвинутый SQL. ...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 7
#   → Extracted skills: ['python', 'pyspark', 'sql', 'pandas', 'python', 'sql', 'pyspark']
# Memory usage: 33.0%
# Processing text: Python, PySpark, Hadoop, Математическая статистика, SQL, pandas, Уверенный Python, продвинутый SQL. ...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 7
#   → Extracted skills: ['python', 'pyspark', 'sql', 'pandas', 'python', 'sql', 'pyspark']
# Memory usage: 33.0%
# Processing text: Power BI, SQL, Python
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 2
#   → Extracted skills: ['sql', 'python']
# Memory usage: 33.0%
# Processing text: SQL, Python, уверенное знание SQL (SELECT, JOIN, агрегатные функции, оконные функции); базовые навык...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 10
#   → Extracted skills: ['sql', 'python', 'sql', 'python', 'pandas', 'matplotlib', 'seaborn', 'amplitude', 'airflow', 'postgresql']
# Processing batch 145–150...
# Memory usage: 32.9%
# Processing text: Python, FastAPI, Pyrogram, asyncio, multiprocessing, threading, SQLAlchemy, Psycopg, Pytest, unittes...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 8
#   → Extracted skills: ['python', 'multiprocessing', 'threading', 'sqlalchemy', 'psycopg', 'rabbitmq', 'sql', 'docker']
# Memory usage: 33.0%
# Processing text: Опыт работы Data Analyst или в аналогичной роли от 3-х лет. Уверенные навыки SQL и опыт работы с бол...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 2
#   → Extracted skills: ['sql', 'mixpanel']
# Memory usage: 33.0%
# Processing text: SQL, СУБД, DWH, Разработка технических заданий, Постановка задач разработчикам
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 1
#   → Extracted skills: ['sql']
# Memory usage: 33.0%
# Processing text: SQL, Clickhouse, ETL
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 1
#   → Extracted skills: ['sql']
# Memory usage: 33.0%
# Processing text: SQL, Python
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 2
#   → Extracted skills: ['sql', 'python']
# Processing batch 150–155...
# Memory usage: 33.0%
# Processing text: Data Science
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 0
#   → Extracted skills: []
# Memory usage: 33.1%
# Processing text: SQL, Python, Power BI, Tableau, FineBI
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 3
#   → Extracted skills: ['sql', 'python', 'tableau']
# Memory usage: 33.1%
# Processing text: SQL, Математическая статистика, Clickhouse, Superset, Python, Работа с базами данных, Аналитическое ...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 2
#   → Extracted skills: ['sql', 'python']
# Memory usage: 33.0%
# Processing text: MySQL, Google Big Query, Python, Hadoop, Git, Английский язык
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 3
#   → Extracted skills: ['mysql', 'python', 'git']
# Memory usage: 33.0%
# Processing text: базовое понимание принципов работы с данными: сбор, очистка, анализ. знание SQL на уровне написания ...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 10
#   → Extracted skills: ['sql', 'tableau', 'google data', 'data studio', 'data studio', 'python', 'r', 'pandas', 'matplotlib', 'seaborn']
# Processing batch 155–160...
# Memory usage: 33.0%
# Processing text: Работа в команде, Адекватность, Анализ данных, Критическое мышление, MS Excel, Ответственность, Тайм...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 1
#   → Extracted skills: ['data analysis']
# Memory usage: 33.1%
# Processing text: SQL, Python, MS SQL
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 3
#   → Extracted skills: ['sql', 'python', 'sql']
# Memory usage: 33.0%
# Processing text: Оптимизация бизнес-процессов, Бизнес-анализ, Аналитическое мышление, Организация работы сотрудников,...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 0
#   → Extracted skills: []
# Memory usage: 33.0%
# Processing text: SQL, Python, Power BI, Продуктовые метрики, Исследовательский анализ данных, Qlik Sense, Unit-эконом...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 2
#   → Extracted skills: ['sql', 'python']
# Memory usage: 33.1%
# Processing text: MS Excel, MS SQL, Python, Работа с системами аналитики, MS Visio, Анализ бизнес-процессов, Автоматиз...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 2
#   → Extracted skills: ['sql', 'python']
# Processing batch 160–165...
# Memory usage: 33.0%
# ...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 5
#   → Extracted skills: ['mongodb', 'pytorch', 'tensorflow', 'python', 'mysql']
# Memory usage: 92.9%
# Processing text: Python, Big Data, Data Analysis
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 2
#   → Extracted skills: ['python', 'data analysis']
# Memory usage: 93.0%
# Processing text: Алгоритмы и структуры данных, GBDT, MLflow, PyTorch, XGBoost, Английский язык, Анализ данных, Monte ...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 4
#   → Extracted skills: ['pytorch', 'xgboost', 'monte carlo', 'machine learning']
# Processing batch 5080–5085...
# Memory usage: 92.7%
# Processing text: DataLens, ETL, Power BI, SQL, Apache Airflow, Fine BI, Python, Tableau, MS Excel
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 3
#   → Extracted skills: ['sql', 'python', 'tableau']
# Memory usage: 92.7%
# Processing text: MLflow, Apache Airflow, SQL, pandas, JupyterHub, Python
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 3
#   → Extracted skills: ['sql', 'pandas', 'python']
# Memory usage: 92.8%
# Processing text: Apache Kafka, Redis, Apache Airflow, PostgreSQL, Prometheus, Grafana, Python
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 5
#   → Extracted skills: ['redis', 'postgresql', 'prometheus', 'grafana', 'python']
# Memory usage: 92.9%
# Processing text: Apache Superset, SQL, BI
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 1
#   → Extracted skills: ['sql']
# Memory usage: 93.0%
# Processing text: SQL, Tableau, A/B тесты, Python, Управление командой
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 4
#   → Extracted skills: ['sql', 'tableau', 'b', 'python']
# Processing batch 5085–5090...
# Memory usage: 93.3%
# Processing text: Olap (online analytical processing), Аналитическое мышление, SQL, Python, MS SQL, Реализованные кейс...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 5
#   → Extracted skills: ['sql', 'python', 'sql', 'python', 'transformers']
# Memory usage: 93.4%
# Processing text: Разработка поисковых технологий, IT
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 0
#   → Extracted skills: []
# Memory usage: 93.5%
# Processing text: Аналитическое мышление, Управление бизнес процессами, Оптимизация бизнес-процессов
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 0
#   → Extracted skills: []
# Memory usage: 93.5%
# Processing text: Amplitude, A/B тесты, Python, SQL
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 4
#   → Extracted skills: ['amplitude', 'b', 'python', 'sql']
# Memory usage: 93.7%
# Processing text: Data Analysis, Data Mining: Statistica, Визуализация данных, Power BI, Ответственность, Soft skills,...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 7
#   → Extracted skills: ['data data', 'data data', 'data mining', 'statistica', 'sql', 'python', 'tableau']
# Processing batch 5090–5095...
# Memory usage: 93.6%
# Processing text: A/B тесты, Python, SQL
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 3
#   → Extracted skills: ['b', 'python', 'sql']
# Memory usage: 93.5%
# Processing text: Big Data, SQL, Бизнес-анализ, Анализ данных
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 3
#   → Extracted skills: ['big data', 'big data', 'data']
# Memory usage: 93.5%
# Processing text: Грамотная письменная речь, Аналитическое мышление, Atlassian Jira, Деловая переписка, Деловая коммун...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 1
#   → Extracted skills: ['jira']
# Memory usage: 93.5%
# Processing text: Преобразование данных, Анализ требований, Математическая статистика, Извлечение данных
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 0
#   → Extracted skills: []
# Memory usage: 93.5%
# Processing text: Преобразование данных, Анализ требований, Математическая статистика, Извлечение данных
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 0
#   → Extracted skills: []
# Processing batch 5095–5100...
# Memory usage: 93.8%
# Processing text: Преобразование данных, Анализ требований, Математическая статистика, Извлечение данных
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 0
#   → Extracted skills: []
# Memory usage: 94.0%
# Processing text: Преобразование данных, Анализ требований, Математическая статистика, Извлечение данных
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 0
#   → Extracted skills: []
# Memory usage: 94.0%
# Processing text: Power Pivot, Power Query, Плюсом будет:, Знание SQL (MS SQL, базовый уровень) Опыт работы в подразде...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 2
#   → Extracted skills: ['sql', 'sql']
# Memory usage: 94.1%
# Processing text: MS PowerPoint, Аналитическое мышление, Деловое общение, Статистический анализ, Сбор и анализ информа...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 0
#   → Extracted skills: []
# Memory usage: 94.3%
# Processing text: Big Data, Data Analysis, nlp, ML, Machine Learning, Python, MS SQL
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 4
#   → Extracted skills: ['data analysis', 'machine learning', 'python', 'sql']
# Processing batch 5100–5105...
# Memory usage: 93.9%
# Processing text: Big Data, Data Analysis, nlp, ML, Machine Learning, Python, MS SQL
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 4
#   → Extracted skills: ['data analysis', 'machine learning', 'python', 'sql']
# Memory usage: 94.0%
# Processing text: Подготовка статистики, Ad-hoc анализ, Визуализация данных, Анализ бизнес показателей, Визуализация, ...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 1
#   → Extracted skills: ['ad hoc']
# Memory usage: 94.0%
# Processing text: MongoDB, API, Data Lens, SQL, Python, Airflow
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 4
#   → Extracted skills: ['mongodb', 'sql', 'python', 'airflow']
# Memory usage: 94.1%
# Processing text: Clickhouse
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 0
#   → Extracted skills: []
# Memory usage: 94.1%
# Processing text: Apache Airflow, Python, SQL
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 2
#   → Extracted skills: ['python', 'sql']
# Processing batch 5105–5110...
# Memory usage: 94.4%
# Processing text: Исследовательский анализ данных, Business Intelligence Systems, Математическая статистика, Power Que...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 3
#   → Extracted skills: ['sql', 'b', 'python']
# Memory usage: 94.1%
# Processing text: Моделирование бизнес процессов, BPMN, Разработка технических заданий, Управление проектами, MS Visio
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 0
#   → Extracted skills: []
# Memory usage: 94.2%
# Processing text: Python, SQL, Hadoop
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 2
#   → Extracted skills: ['python', 'sql']
# Memory usage: 94.4%
# Processing text: Big Data, ORACLE, Визуализация данных, Power BI, Matplotlib, Python, Greenplum, Английский язык, Pos...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 7
#   → Extracted skills: ['matplotlib', 'python', 'greenplum', 'postgresql', 'mysql', 'plotly', 'devops']
# Memory usage: 94.5%
# Processing text: Atlassian Confluence, MongoDB, Apache Cassandra, Apache Kafka, Apache Airflow
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 1
#   → Extracted skills: ['mongodb']
# Processing batch 5110–5115...
# Memory usage: 94.1%
# Processing text: Atlassian Confluence, MongoDB, Apache Cassandra, Apache Kafka, Apache Airflow
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 1
#   → Extracted skills: ['mongodb']
# Memory usage: 92.8%
# Processing text: Формирование аналитической отчетности, Входной контроль, Основы баз данных, Производство строительно...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 0
#   → Extracted skills: []
# Memory usage: 82.6%
# Processing text: A/B тесты, Python, SQL, ETL
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 3
#   → Extracted skills: ['b', 'python', 'sql']
# Memory usage: 68.7%
# Processing text: Big Data, SoapUI, CI/CD, ETL, Power BI, Apache Airflow, SQL, pandas, Grafana, Git, Python
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 6
#   → Extracted skills: ['soapui', 'sql', 'pandas', 'grafana', 'git', 'python']
# Memory usage: 55.3%
# Processing text: Power Pivot, MS PowerPoint, Power Query, Tableau, MS Excel
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 1
#   → Extracted skills: ['tableau']
# Processing batch 5115–5120...
# Memory usage: 35.4%
# Processing text: Power BI, SQL, Бизнес-анализ, Анализ данных, Работа с базами данных
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 1
#   → Extracted skills: ['sql']
# Memory usage: 35.4%
# Processing text: MLflow, IT, поиск, ML, Hadoop, Разработка поисковых технологий, Python, Spark
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 1
#   → Extracted skills: ['python']
# Memory usage: 35.5%
# Processing text: Numpy, Deep Learning, Matplotlib, PyTorch, Английский язык, pandas, Python
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 6
#   → Extracted skills: ['numpy', 'deep learning', 'matplotlib', 'pytorch', 'pandas', 'python']
# Memory usage: 35.6%
# Processing text: Разработка поисковых технологий, IT
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 0
#   → Extracted skills: []
# Memory usage: 35.7%
# Processing text: Визуализация данных, Power BI, Математическая статистика, dbt, Metabase, SQL, Английский язык, MySQL...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 3
#   → Extracted skills: ['sql', 'mysql', 'python']
# Processing batch 5120–5125...
# Memory usage: 36.0%
# Processing text: Python, SQL, АБ тестирование
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 2
#   → Extracted skills: ['python', 'sql']
# Memory usage: 36.2%
# Processing text: СУБД, Интервьюирование, DWH, Сбор требований, Greenplum, SQL, BI, PostgreSQL, Бизнес-анализ, Ведение...
#   → Found annotations: keys=['text', 'results'], results keys=['full_matches', 'ngram_scored']
#   → ngram_scored count: 3
#   → Extracted skills: ['greenplum', 'sql', 'postgresql']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 37
#      34 print(f"Processing batch {i}–{i+batch_size}...")
#      36 batch = cleaned_data.iloc[i:i+batch_size].copy()
# ---> 37 batch['requirements'] = batch['requirements'].apply(extract_hard_skills)
#      39 results.append(batch)
#      41 time.sleep(1)
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/pandas/core/series.py:4935, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4800 def apply(
#    4801     self,
#    4802     func: AggFuncType,
#    (...)   4807     **kwargs,
#    4808 ) -> DataFrame | Series:
#    4809     """
#    4810     Invoke function on values of Series.
#    4811
#    (...)   4926     dtype: float64
#    4927     """
#    4928     return SeriesApply(
#    4929         self,
#    4930         func,
#    4931         convert_dtype=convert_dtype,
#    4932         by_row=by_row,
#    4933         args=args,
#    4934         kwargs=kwargs,
# -> 4935     ).apply()
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/pandas/core/apply.py:1422, in SeriesApply.apply(self)
#    1419     return self.apply_compat()
#    1421 # self.func is Callable
# -> 1422 return self.apply_standard()
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/pandas/core/apply.py:1502, in SeriesApply.apply_standard(self)
#    1496 # row-wise access
#    1497 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1498 # we need to give `na_action="ignore"` for categorical data.
#    1499 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1500 #  Categorical (GH51645).
#    1501 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1502 mapped = obj._map_values(
#    1503     mapper=curried, na_action=action, convert=self.convert_dtype
#    1504 )
#    1506 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1507     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1508     #  See also GH#25959 regarding EA support
#    1509     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/pandas/core/base.py:925, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     922 if isinstance(arr, ExtensionArray):
#     923     return arr.map(mapper, na_action=na_action)
# --> 925 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~/miniconda3/envs/myenv/lib/python3.11/site-packages/pandas/core/algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2999, in pandas._libs.lib.map_infer()
#
# Cell In[7], line 2, in extract_hard_skills(text)
#       1 def extract_hard_skills(text):
# ----> 2     time.sleep(0.2)
#       3     print(f"Memory usage: {psutil.virtual_memory().percent}%")
#       4     print(f"Processing text: {text[:100]}..." if len(text) > 100 else f"Processing text: {text}")
#
# KeyboardInterrupt:

# %%
def is_empty_array(val):
    try:
        lst = ast.literal_eval(val)
        return isinstance(lst, list) and len(lst) == 0
    except (ValueError, SyntaxError):
        return False 

data = pd.read_csv(f'{PR_DATA_PATH}requirements_data_processed.csv')
data['requirements'] = data['requirements'].replace(r'^\s*$', pd.NA, regex=True)
data = data.dropna(subset=['requirements'])

mask_not_empty = ~data['requirements'].apply(lambda x: is_empty_array(x))

data['requirements'] = data['requirements'].replace(r'^\s*$', pd.NA, regex=True)
data = data.dropna(subset=['requirements'])

data = data[mask_not_empty]

data.to_csv(f'{PR_DATA_PATH}requirements_data_processed_cleaned.csv', index=False)
